# %% [markdown]
# <a href="https://colab.research.google.com/github/uppupushpa/practice/blob/main/Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mean Squared Error
from sklearn.metrics import mean_squared_error
actual=[10,20,30]
predicted=[12,18,35]
loss=mean_squared_error(actual,predicted)
print(loss)
# Out:
# 11.0

# %%
#Binary Cross Entropy
from sklearn.metrics import log_loss
actual=[1,0,1]
prediction=[0.9,0.2,0.8]
print(log_loss(actual,prediction))
# Out:
# 0.18388253942874858

# %%
from tensorflow.keras.losses import CategoricalCrossentropy

# %%
#Backward Propagation
#Initial values
weight = 2.5
gradient=0.8
learning_rate=0.1

new_weight=weight - learning_rate * gradient

print("Old Weight:", weight)
print("Gradient:", gradient)
print("New Weight:", new_weight)
# Out:
# Old Weight: 2.5
# Gradient: 0.8
# New Weight: 2.42

# %%
#Gradient Descent
weight=5
gradient=3
learning_rate=0.1

for epoch in range(5):
  weight=weight - learning_rate * gradient
  print(f"Epoch {epoch+1}: Weight = {weight:.2f}")
# Out:
# Epoch 1: Weight = 4.70
# Epoch 2: Weight = 4.40
# Epoch 3: Weight = 4.10
# Epoch 4: Weight = 3.80
# Epoch 5: Weight = 3.50

# %%
# ==========================================
# Building a Neural Network using TensorFlow/Keras
# Example: Predict Pass/Fail based on Study Hours
# ==========================================

# Step 1: Import Libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# ------------------------------------------
# Step 2: Create Dataset
# ------------------------------------------

# Input (Study Hours)
X = np.array([
    [2],
    [4],
    [6],
    [8],
    [10]
])

# Output (0 = Fail, 1 = Pass)
y = np.array([
    0,
    0,
    1,
    1,
    1
])

# ------------------------------------------
# Step 3: Build Neural Network
# ------------------------------------------

model = Sequential([
    Dense(8, activation='relu', input_shape=(1,)),   # Hidden Layer 1
    Dense(4, activation='relu'),                     # Hidden Layer 2
    Dense(1, activation='sigmoid')                   # Output Layer
])

# ------------------------------------------
# Step 4: Compile the Model
# ------------------------------------------

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# ------------------------------------------
# Step 5: Train the Model
# ------------------------------------------

print("Training Started...\n")

history = model.fit(
    X,
    y,
    epochs=100,
    verbose=1
)

print("\nTraining Completed!")

# ------------------------------------------
# Step 6: Evaluate the Model
# ------------------------------------------

loss, accuracy = model.evaluate(X, y, verbose=0)

print("\nModel Evaluation")
print("-----------------------")
print("Loss     :", round(loss, 4))
print("Accuracy :", round(accuracy * 100, 2), "%")

# ------------------------------------------
# Step 7: Make Predictions
# ------------------------------------------

print("\nPredictions")
print("-----------------------")

test_data = np.array([
    [3],
    [5],
    [7],
    [9]
])

predictions = model.predict(test_data)

for hours, pred in zip(test_data, predictions):
    probability = pred[0]

    if probability >= 0.5:
        result = "Pass"
    else:
        result = "Fail"

    print(f"Study Hours: {hours[0]} -> Probability: {probability:.4f} -> Prediction: {result}")

# ------------------------------------------
# Step 8: Model Summary
# ------------------------------------------

print("\nModel Summary")
print("-----------------------")
model.summary()

# ------------------------------------------
# Step 9: Display Weights and Biases
# ------------------------------------------

print("\nModel Weights and Biases")
print("-----------------------")

for i, layer in enumerate(model.layers):
    weights, biases = layer.get_weights()

    print(f"\nLayer {i+1}")
    print("Weights:")
    print(weights)

    print("Biases:")
    print(biases)

# ------------------------------------------
# Step 10: Predict for a New Student
# ------------------------------------------

study_hours = 3

prediction = model.predict(np.array([[study_hours]]))

print("\nNew Student Prediction")
print("-----------------------")
print("Study Hours :", study_hours)
print("Probability :", prediction[0][0])

if prediction[0][0] >= 0.5:
    print("Final Prediction : PASS")
else:
    print("Final Prediction : FAIL")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training Started...
#
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6000 - loss: 0.5344
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.6000 - loss: 0.5335
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6000 - loss: 0.5327
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.5319
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6000 - loss: 0.5312
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6000 - loss: 0.5305
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6000 - loss: 0.5299
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6000 - loss: 0.5293
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6000 - loss: 0.5288
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6000 - loss: 0.5283
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6000 - loss: 0.5278
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6000 - loss: 0.5274
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6000 - loss: 0.5270
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6000 - loss: 0.5266
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6000 - loss: 0.5263
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6000 - loss: 0.5260
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6000 - loss: 0.5256
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6000 - loss: 0.5253
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6000 - loss: 0.5250
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6000 - loss: 0.5246
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6000 - loss: 0.5243
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6000 - loss: 0.5239
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6000 - loss: 0.5236
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6000 - loss: 0.5232
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6000 - loss: 0.5228
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6000 - loss: 0.5224
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6000 - loss: 0.5220
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6000 - loss: 0.5216
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6000 - loss: 0.5212
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6000 - loss: 0.5208
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6000 - loss: 0.5204
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6000 - loss: 0.5200
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6000 - loss: 0.5196
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6000 - loss: 0.5193
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6000 - loss: 0.5189
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6000 - loss: 0.5185
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.6000 - loss: 0.5181
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6000 - loss: 0.5177
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6000 - loss: 0.5173
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.5169
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6000 - loss: 0.5165
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6000 - loss: 0.5162
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6000 - loss: 0.5158
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6000 - loss: 0.5154
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6000 - loss: 0.5150
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.5146
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6000 - loss: 0.5142
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6000 - loss: 0.5138
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.5134
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6000 - loss: 0.5130
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.5126
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.5122
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.5118
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6000 - loss: 0.5114
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.6000 - loss: 0.5110
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6000 - loss: 0.5106
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.5101
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6000 - loss: 0.5097
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6000 - loss: 0.5093
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6000 - loss: 0.5089
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.5085
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6000 - loss: 0.5081
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6000 - loss: 0.5076
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6000 - loss: 0.5072
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.5068
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.5064
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.5059
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.5055
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6000 - loss: 0.5051
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6000 - loss: 0.5046
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6000 - loss: 0.5042
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.5038
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6000 - loss: 0.5033
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6000 - loss: 0.5029
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.5024
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6000 - loss: 0.5020
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6000 - loss: 0.5015
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6000 - loss: 0.5011
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6000 - loss: 0.5006
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6000 - loss: 0.5002
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6000 - loss: 0.4997
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6000 - loss: 0.4992
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6000 - loss: 0.4988
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6000 - loss: 0.4983
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6000 - loss: 0.4978
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6000 - loss: 0.4974
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6000 - loss: 0.4969
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6000 - loss: 0.4964
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6000 - loss: 0.4959
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6000 - loss: 0.4954
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6000 - loss: 0.4949
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6000 - loss: 0.4944
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6000 - loss: 0.4939
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6000 - loss: 0.4934
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.4929
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.4924
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6000 - loss: 0.4919
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6000 - loss: 0.4914
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6000 - loss: 0.4909
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.4904
#
# Training Completed!
#
# Model Evaluation
# -----------------------
# Loss     : 0.4898
# Accuracy : 60.0 %
#
# Predictions
# -----------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Study Hours: 3 -> Probability: 0.6093 -> Prediction: Pass
# Study Hours: 5 -> Probability: 0.7170 -> Prediction: Pass
# Study Hours: 7 -> Probability: 0.8045 -> Prediction: Pass
# Study Hours: 9 -> Probability: 0.8698 -> Prediction: Pass
#
# Model Summary
# -----------------------
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 173 (696.00 B)
#  Trainable params: 57 (228.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 116 (468.00 B)
# Model Weights and Biases
# -----------------------
#
# Layer 1
# Weights:
# [[-0.06606776  0.37334636  0.17928602  0.39576754 -0.77721864 -0.20650905
#    0.45282418 -0.76028913]]
# Biases:
# [ 0.         -0.09844458 -0.10666312 -0.09885435  0.          0.
#   0.10109109  0.        ]
#
# Layer 2
# Weights:
# [[-6.5140843e-02 -3.3590019e-02  2.0288634e-01  5.6231672e-01]
#  [ 4.5502642e-01  4.8244128e-01 -3.4342399e-01 -3.9344874e-01]
#  [ 8.1050716e-02 -6.7885965e-01  1.9079369e-01  8.5957289e-02]
#  [ 6.9878620e-01  1.7719644e-01  3.5453260e-02 -8.3036184e-02]
#  [ 4.1865784e-01 -1.6856194e-04 -3.6651674e-01  5.6937891e-01]
#  [-1.6265428e-01 -5.2797931e-01  6.3706523e-01  6.0280818e-01]
#  [-1.6502173e-01  3.5267033e-02 -1.1426586e-01 -4.4618812e-01]
#  [ 5.9170514e-01  5.8684331e-01 -1.1249185e-02  5.8494276e-01]]
# Biases:
# [-0.09844225  0.10270492  0.          0.        ]
#
# Layer 3
# Weights:
# [[ 0.69516724]
#  [-0.18002602]
#  [-1.0516171 ]
#  [ 0.07472908]]
# Biases:
# [-0.09732702]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
#
# New Student Prediction
# -----------------------
# Study Hours : 3
# Probability : 0.6093255
# Final Prediction : PASS
